# %%
import random
import string
import warnings

import nltk
import speech_recognition as sr 
import pyttsx3
from nltk.stem import WordNetLemmatizer

warnings.filterwarnings("ignore")

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("wordnet")
nltk.download("omw-1.4")  

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
intents = {

    "greeting": {
        "patterns": ["hi", "hello", "hey", "good morning", "good evening", "how are you"],
        "responses": [
            "Hello! Welcome to the Mental Wellness Chatbot.",
            "Hi there! I'm here to support you.",
            "Welcome! How are you feeling today?"
        ],
    },

    "goodbye": {
        "patterns": ["bye", "goodbye", "see you", "exit", "quit"],
        "responses": [
            "Take care of yourself. Goodbye!",
            "Stay positive and have a wonderful day.",
            "See you again. Remember to be kind to yourself."
        ],
    },

    "thanks": {
        "patterns": ["thank you", "thanks", "thanks a lot"],
        "responses": [
            "You're welcome!",
            "I'm always here to help.",
            "Glad I could support you."
        ],
    },

    "feeling_happy": {
        "patterns": ["i am happy", "i feel happy", "feeling good"],
        "responses": [
            "That's wonderful! Keep enjoying the positive moments.",
            "I'm happy to hear that!"
        ],
    },

    "feeling_sad": {
        "patterns": ["i am sad", "i feel sad", "feeling down"],
        "responses": [
            "I'm sorry you're feeling sad. Remember that difficult feelings will pass.",
            "It's okay to feel sad sometimes. You're not alone."
        ],
    },

    "feeling_stressed": {
        "patterns": ["i am stressed", "stress", "feeling stressed"],
        "responses": [
            "Take a slow deep breath. You are stronger than your stress.",
            "A short break and deep breathing may help."
        ],
    },

    "feeling_anxious": {
        "patterns": ["i am anxious", "anxiety", "worried"],
        "responses": [
            "Try focusing on your breathing for a few moments.",
            "Remember, you only need to take one step at a time."
        ],
    },

    "feeling_angry": {
        "patterns": ["i am angry", "angry", "mad"],
        "responses": [
            "Take a deep breath before reacting.",
            "It's okay to feel angry. Try expressing it calmly."
        ],
    },

    "feeling_lonely": {
        "patterns": ["i feel lonely", "lonely", "alone"],
        "responses": [
            "You are not alone. Consider talking to someone you trust.",
            "Sometimes reaching out to a friend can make a difference."
        ],
    },

    "feeling_tired": {
        "patterns": ["i am tired", "exhausted", "no energy"],
        "responses": [
            "Your body may need rest. Try to take a short break.",
            "Rest is an important part of wellness."
        ],
    },

    "breathing_exercise": {
        "patterns": ["breathing exercise", "help me breathe", "deep breathing"],
        "responses": [
            "Inhale slowly for four seconds, hold for four, then exhale for four.",
            "Take slow deep breaths and relax your shoulders."
        ],
    },

    "meditation": {
        "patterns": ["meditation", "meditate", "mindfulness"],
        "responses": [
            "Close your eyes and focus on your breathing.",
            "Spend five minutes noticing each breath."
        ],
    },

    "positive_affirmation": {
        "patterns": ["affirmation", "positive words", "encourage me"],
        "responses": [
            "You are capable, strong, and worthy.",
            "Believe in yourself. Every day is a new beginning."
        ],
    },

    "motivation": {
        "patterns": ["motivate me", "motivation"],
        "responses": [
            "Small steps every day lead to big achievements.",
            "You are stronger than you think."
        ],
    },

    "self_confidence": {
        "patterns": ["confidence", "self confidence"],
        "responses": [
            "Believe in your abilities. You are capable.",
            "Confidence grows with practice."
        ],
    },

    "self_care": {
        "patterns": ["self care", "take care of myself"],
        "responses": [
            "Drink water, rest well, and be kind to yourself.",
            "Self-care is not selfish; it's necessary."
        ],
    },

    "sleep_help": {
        "patterns": ["can't sleep", "sleep problem", "insomnia"],
        "responses": [
            "Try avoiding screens before bedtime and practice deep breathing.",
            "A calm bedtime routine can improve sleep."
        ],
    },

    "exercise": {
        "patterns": ["exercise", "workout", "fitness"],
        "responses": [
            "Even a short walk can improve your mood.",
            "Physical activity helps both body and mind."
        ],
    },

    "healthy_food": {
        "patterns": ["healthy food", "nutrition", "diet"],
        "responses": [
            "Balanced meals support both physical and mental wellness.",
            "Eating nutritious food can improve your energy."
        ],
    },

    "drink_water": {
        "patterns": ["drink water", "hydration"],
        "responses": [
            "Remember to stay hydrated throughout the day.",
            "Water helps your body and mind function well."
        ],
    },

    "gratitude": {
        "patterns": ["gratitude", "thankful"],
        "responses": [
            "Think of three things you're grateful for today.",
            "Gratitude helps create a positive mindset."
        ],
    },

    "journal": {
        "patterns": ["journal", "write my thoughts"],
        "responses": [
            "Writing your thoughts can help reduce stress.",
            "Journaling is a healthy way to express emotions."
        ],
    },

    "relaxation": {
        "patterns": ["relax", "calm me down"],
        "responses": [
            "Take a slow breath and relax your muscles.",
            "Imagine yourself in a peaceful place."
        ],
    },

    "panic_help": {
        "patterns": ["panic", "panic attack"],
        "responses": [
            "Focus on slow breathing and notice five things around you.",
            "Ground yourself by noticing what you can see and hear."
        ],
    },

    "overthinking": {
        "patterns": ["overthinking", "thinking too much"],
        "responses": [
            "Try focusing on what you can control today.",
            "Take one small step instead of thinking about everything."
        ],
    },

    "fear": {
        "patterns": ["i am scared", "fear"],
        "responses": [
            "It's okay to feel afraid. Courage begins with one step.",
            "Take a deep breath and remind yourself that you can handle this."
        ],
    },

    "failure": {
        "patterns": ["i failed", "failure"],
        "responses": [
            "Failure is an opportunity to learn and grow.",
            "Every successful person has faced setbacks."
        ],
    },

    "success": {
        "patterns": ["success", "achievement"],
        "responses": [
            "Celebrate your achievements, no matter how small.",
            "Success comes through consistent effort."
        ],
    },

    "goal_setting": {
        "patterns": ["set goals", "goal"],
        "responses": [
            "Break your goals into small achievable steps.",
            "One step at a time leads to success."
        ],
    },

    "time_management": {
        "patterns": ["manage time", "time management"],
        "responses": [
            "Create a simple to-do list and prioritize important tasks.",
            "Planning your day reduces stress."
        ],
    },

    "study_stress": {
        "patterns": ["exam stress", "study stress"],
        "responses": [
            "Take regular breaks while studying.",
            "Believe in your preparation."
        ],
    },

    "work_stress": {
        "patterns": ["work stress", "office stress"],
        "responses": [
            "Take short breaks and avoid multitasking.",
            "Remember to maintain a healthy work-life balance."
        ],
    },

    "relationship": {
        "patterns": ["relationship problem", "family issue"],
        "responses": [
            "Open communication often helps solve misunderstandings.",
            "Listen calmly and express your feelings respectfully."
        ],
    },

    "friendship": {
        "patterns": ["friend problem", "friendship"],
        "responses": [
            "Honest communication strengthens friendships.",
            "Good friends support each other."
        ],
    },

    "mindfulness": {
        "patterns": ["be present", "mindful"],
        "responses": [
            "Focus on the present moment instead of worrying about tomorrow.",
            "Notice your breathing and surroundings."
        ],
    },

    "smile": {
        "patterns": ["make me smile", "smile"],
        "responses": [
            "A smile can brighten your day and someone else's too.",
            "Keep smiling. Better days are ahead."
        ],
    },

    "hobby": {
        "patterns": ["suggest hobby", "hobby"],
        "responses": [
            "Reading, painting, music, or gardening can improve your mood.",
            "Trying a new hobby can reduce stress."
        ],
    },

    "music": {
        "patterns": ["music", "listen to music"],
        "responses": [
            "Relaxing music can help reduce stress.",
            "Your favorite songs can lift your mood."
        ],
    },

    "nature": {
        "patterns": ["nature", "go outside"],
        "responses": [
            "Spending time in nature helps refresh your mind.",
            "A short walk outdoors can improve your mood."
        ],
    },

    "kindness": {
        "patterns": ["kindness", "be kind"],
        "responses": [
            "Kindness towards yourself and others creates happiness.",
            "Small acts of kindness make a big difference."
        ],
    },

    "forgiveness": {
        "patterns": ["forgive", "forgiveness"],
        "responses": [
            "Forgiveness brings peace to your heart.",
            "Letting go helps you move forward."
        ],
    },

    "hope": {
        "patterns": ["hope", "give me hope"],
        "responses": [
            "Every new day is a fresh opportunity.",
            "Hope is stronger than fear."
        ],
    },

    "resilience": {
        "patterns": ["be strong", "resilience"],
        "responses": [
            "You have overcome challenges before, and you can do it again.",
            "Strength grows through difficult times."
        ],
    },

    "daily_tip": {
        "patterns": ["daily tip", "wellness tip"],
        "responses": [
            "Today's tip: Drink water, stretch, and take deep breaths.",
            "Remember to take small breaks throughout the day."
        ],
    },

    "quote": {
        "patterns": ["quote", "inspiring quote"],
        "responses": [
            "Believe you can, and you're halfway there.",
            "Every day is a chance to grow."
        ],
    },

    "mental_health_info": {
        "patterns": ["mental health", "what is mental wellness"],
        "responses": [
            "Mental wellness means taking care of your emotional, psychological, and social well-being."
        ],
    },

    "help": {
        "patterns": ["help", "support"],
        "responses": [
            "I'm here to listen and provide general wellness support.",
            "Tell me how you're feeling today."
        ],
    },

    "emergency": {
        "patterns": ["i need urgent help", "crisis", "emergency"],
        "responses": [
            "I'm sorry you're going through this. Please contact a trusted family member, friend, or a mental health professional immediately."
        ],
    },

    "fallback": {
        "patterns": [],
        "responses": [
            "I'm sorry, I didn't understand. Could you rephrase your question?",
            "Can you tell me more about how you're feeling?",
            "I'm here to support your mental wellness."
        ],
    },
}

print(f"Loaded {len(intents)} intents.")
# Out:
# Loaded 49 intents.

# %%
def preprocess(text: str):
    """Lowercase, strip punctuation, tokenize, and lemmatize a string."""
    text = text.lower().translate(str.maketrans("", "", string.punctuation))
    tokens = nltk.word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(tok) for tok in tokens]
    return lemmas

print(preprocess("Hello! how are you?"))
# Out:
# ['hello', 'how', 'are', 'you']

# %%
processed_patterns = {
    tag: [preprocess(p) for p in data["patterns"]]
    for tag, data in intents.items()
}


def score_intent(user_tokens, pattern_tokens):
    """Overlap score between user tokens and a single pattern's tokens."""
    if not pattern_tokens:
        return 0.0
    overlap = len(set(user_tokens) & set(pattern_tokens))
    return overlap / len(set(pattern_tokens))


def match_intent(user_text, threshold=0.4):
    user_tokens = preprocess(user_text)
    best_tag, best_score = "fallback", 0.0

    for tag, pattern_list in processed_patterns.items():
        if tag == "fallback":
            continue
        for pattern_tokens in pattern_list:
            score = score_intent(user_tokens, pattern_tokens)
            if score > best_score:
                best_score, best_tag = score, tag

    if best_score < threshold:
        return "fallback"
    return best_tag


def get_response(user_text):
    tag = match_intent(user_text)
    return random.choice(intents[tag]["responses"])


# Quick test
for test in ["hey", "wellness tip", "how are you", "asdkjhasd"]:
    print(f"{test!r:30s} -> {get_response(test)}")
# Out:
# 'hey'                          -> Hello! Welcome to the Mental Wellness Chatbot.
# 'wellness tip'                 -> Today's tip: Drink water, stretch, and take deep breaths.
# 'how are you'                  -> Hello! Welcome to the Mental Wellness Chatbot.
# 'asdkjhasd'                    -> I'm here to support your mental wellness.

# %%
def speak(text: str, rate: int = 175, volume: float = 1.0):
    """Speak the given text out loud using pyttsx3."""
    engine = pyttsx3.init()
    engine.setProperty("rate", rate)
    engine.setProperty("volume", volume)
    engine.say(text)
    engine.runAndWait()
    engine.stop()

# %%
def listen(timeout=5, phrase_time_limit=8): 
    """Record from the microphone and return the transcribed text, or None on failure."""
    recognizer = sr.Recognizer() 
    with sr.Microphone() as source:
        print("🎤 Listening... (speak now)")
        recognizer.adjust_for_ambient_noise(source, duration=0.5)
        try:
            audio = recognizer.listen(source, timeout=timeout, phrase_time_limit=phrase_time_limit)
        except sr.WaitTimeoutError:
            print("⏱️ Listening timed out — no speech detected.")
            return None

    try:
        text = recognizer.recognize_google(audio)
        print(f"🗣️ You said: {text}")
        return text
    except sr.UnknownValueError:
        print("😕 Could not understand the audio.")
        return None
    except sr.RequestError as e:
        print(f"⚠️ Speech recognition service error: {e}")
        return None


print("listen() function ready.")
# Out:
# listen() function ready.

# %%
def run_voice_chatbot(max_turns=40):
    print("Voice chatbot started. Say something! (say 'bye' to stop)\n")
    speak("Hello! I am your voice assistant. How can I help you?")

    for _ in range(max_turns):
        user_text = listen()
        if user_text is None:
            continue

        tag = match_intent(user_text)
        response = get_response(user_text)
        print(f"🤖 Bot: {response}")
        speak(response)

        if tag == "goodbye":
            break
    else:
        print("Reached max turns for this session.")


run_voice_chatbot()
# Out:
# Voice chatbot started. Say something! (say 'bye' to stop)
#
# 🎤 Listening... (speak now)
# 🗣️ You said: hello hello
# 🤖 Bot: Hello! Welcome to the Mental Wellness Chatbot.
# 🎤 Listening... (speak now)
# 😕 Could not understand the audio.
# 🎤 Listening... (speak now)
# 🗣️ You said: I am happy
# 🤖 Bot: I'm happy to hear that!
# 🎤 Listening... (speak now)
# 🗣️ You said: I am stressed
# 🤖 Bot: A short break and deep breathing may help.
# 🎤 Listening... (speak now)
# 🗣️ You said: I am tired
# 🤖 Bot: Rest is an important part of wellness.
# 🎤 Listening... (speak now)
# 🗣️ You said: bre
# 🤖 Bot: Can you tell me more about how you're feeling?
# 🎤 Listening... (speak now)
# 🗣️ You said: help me bre
# 🤖 Bot: I'm here to listen and provide general wellness support.
# 🎤 Listening... (speak now)
# 😕 Could not understand the audio.
# 🎤 Listening... (speak now)
# 🗣️ You said: motivate
# 🤖 Bot: You are stronger than you think.
# 🎤 Listening... (speak now)
# 🗣️ You said: selfcare
# ...
