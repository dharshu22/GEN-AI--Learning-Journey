# %%
import spacy
nlp=spacy.load('en_core_web_sm')

word1=nlp('Lion')
word2=nlp('Tiger')

print('similarities between',word1.text,'and',word2.text,'is',word1.similarity(word2))
# Out:
# similarities between Lion and Tiger is 0.4450088441371918
# C:\Users\vishn\AppData\Local\Temp\ipykernel_23604\1570666478.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print('similarities between',word1.text,'and',word2.text,'is',word1.similarity(word2))

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

word1=nlp('Human')
word2=nlp('Chimpanzees')

print('similarities between',word1.text,'and',word2.text,'is',word1.similarity(word2))
# Out:
# similarities between Human and Chimpanzees is 0.1810562014579773
# C:\Users\vishn\AppData\Local\Temp\ipykernel_23604\655370176.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print('similarities between',word1.text,'and',word2.text,'is',word1.similarity(word2))

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

sent1=nlp('The sun rises in the east.')
sent2=nlp('The moon shines brightly at night. ')

print('similarities between',sent1.text,'and',sent2.text,'is',sent1.similarity(sent2))
# Out:
# similarities between The sun rises in the east. and The moon shines brightly at night.  is 0.6957353949546814
# C:\Users\vishn\AppData\Local\Temp\ipykernel_23604\1517715548.py:11: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print('similarities between',sent1.text,'and',sent2.text,'is',sent1.similarity(sent2))

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

sent1=nlp('I like to drink coffee every morning.')
sent2=nlp('I like to drink tea every morning. ')

print('similarities between',sent1.text,'and',sent2.text,'is',sent1.similarity(sent2))
# Out:
# similarities between I like to drink coffee every morning. and I like to drink tea every morning.  is 0.9679291844367981
# C:\Users\vishn\AppData\Local\Temp\ipykernel_23604\1801222581.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print('similarities between',sent1.text,'and',sent2.text,'is',sent1.similarity(sent2))
